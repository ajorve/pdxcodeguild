# %%
import matplotlib.pyplot as plt
from crime import run_program
# %matplotlib inline

# %%
cd /Users/Anders/Desktop/PDX_Code/practice/projects/pdx_crime_data/data/
# Out:
# C:\Users\Anders\Desktop\PDX_Code\practice\projects\pdx_crime_data\data

# %%
result, crimes = run_program()
# Out:
# To find out the list of crimes and occurrence by file, please select from the options
# 0 >> crime_incident_data_2011.csv
# 1 >> crime_incident_data_2012.csv
# 2 >> crime_incident_data_2013.csv
# 3 >> crime_incident_data_2014.csv
# 4 >> crime_incident_data_recent.csv
# or
# q) Quit
# Please make your selection. >> 3

# %%
# y = list(sorted(crimes.values(), reverse=True))
# N = len(y)    #  result[1]
# x = list(crimes.keys())
# # width = 1/1.5
# plt.bar(left=x, height=y, color='blue')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-2e98d4bb83d4> in <module>()
#       3 x = list(crimes.keys())
#       4 # width = 1/1.5
# ----> 5 plt.bar(left=x, height=y, color='blue')
#       6 plt.show()
#
# C:\Users\Anders\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2648     try:
#    2649         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2650                      **kwargs)
#    2651     finally:
#    2652         ax.hold(washold)
#
# C:\Users\Anders\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
# ...

# %%
# crimes = sorted(crimes.items(), key=lambda t: t[1])

offenses = list(crimes.values())
clabels = list(crimes.keys())


fig1, ax1 = plt.subplots()

explode = [0.1 for _ in range(len(offenses))]
# explode[-1] = 0.5

autopct = '%1.1f%%'

ax1.pie(offenses, labels=clabels, startangle=90, labeldistance=1.2, explode=explode)
ax1.axis('equal')

plt.show()
